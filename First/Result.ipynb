# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot
import glob
# %matplotlib inline

# %%
names = ['realaviation','simaviation','realauto','simauto']
numFiles = [0]
for i in range(4):
    numFiles.append(len(glob.glob('sraa/'+names[i]+'/*')))
    numFiles[i+1] += numFiles[i]

# %%
with open('run2/vecs.txt','r') as f:
    a = []
    for line in f:
        a.append(map(float,line.split()[:10]))

data= pd.DataFrame(a)
        
data.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.000881 -0.000008  0.000185  0.000008  0.000014 -0.000005 -0.000289
# 1 -0.000881 -0.000008  0.000314 -0.000014  0.000024 -0.000013 -0.000093
# 2 -0.000881 -0.000010  0.000098 -0.000009  0.000016 -0.000005 -0.000116
# 3 -0.000881 -0.000013  0.000004 -0.000006  0.000012 -0.000004 -0.000224
# 4 -0.000881 -0.000007  0.000233 -0.000012  0.000015 -0.000007 -0.000321
#
#           7         8         9
# 0  0.000095  0.000032  0.000028
# 1  0.000043  0.000018  0.000036
# 2  0.000044  0.000024  0.000025
# 3  0.000075  0.000031  0.000029
# 4  0.000109  0.000035  0.000041

# %%
numFeatures = 223777
N = data.shape[0]

# %%
mask = []
for i in range(4):
    mask.append(np.zeros(N,dtype=int))
    mask[i][numFeatures+numFiles[i]:numFeatures+numFiles[i+1]] = np.ones(numFiles[i+1]-numFiles[i],dtype=int)

# %%
for i in range(4):
    print mask[i].shape,mask[i].sum()
# Out:
# (296997L,) 17445
# (296997L,) 9626
# (296997L,) 4796
# (296997L,) 41351

# %%
samples = []
for i in range(4):
    samples.append(data[mask[i] == 1])

# %%
data.tail(40)
# Out:
#                0         1         2         3         4         5         6  \
# 296957  0.000881  0.000006 -0.000266  0.000013 -0.000019  0.000008  0.000275
# 296958  0.000881  0.000005 -0.000311  0.000012  0.000017  0.000006  0.000476
# 296959  0.000881  0.000007 -0.000351  0.000015 -0.000022  0.000007  0.000574
# 296960  0.000881  0.000006 -0.000395  0.000015 -0.000025  0.000011  0.000433
# 296961  0.000881 -0.000026 -0.000399  0.000017 -0.000022  0.000011  0.000234
# 296962  0.000881  0.000009 -0.000197  0.000010 -0.000013  0.000007  0.000400
# 296963  0.000881  0.000004 -0.000247  0.000011 -0.000021  0.000005  0.000348
# 296964  0.000881  0.000008 -0.000365  0.000013 -0.000022  0.000010  0.000271
# 296965  0.000881 -0.000003 -0.000515  0.000021 -0.000032  0.000015  0.000006
# 296966  0.000881  0.000007 -0.000341  0.000015 -0.000021  0.000007  0.000542
# 296967  0.000881 -0.000168 -0.000011  0.000008  0.000272 -0.000029  0.000488
# ...
